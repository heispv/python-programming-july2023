# %% [markdown]
# <a href="https://colab.research.google.com/github/heispv/python-programming-july2023/blob/master/03_python_programming_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.
#
# Barname zir ro kamel konid.
#
# in barname yek seri chiz hayi dare ke hanooz yad nagereftin va faghat baraye ine ke ba ghodrat haye barname nevisi ashna beshin.

# %%
while True: # in yek halghe hast ke bi nahat bar micharkhe ta `break` she
  my_text = input('Esm va family khod ra ba hurufe avvale bozorg vared konid.\
  \nExample) Peyman Vahidi\n\nEsm va family shoma: ')


  if len(my_text.split()) == 2: # in ghesmat miad check mikone bebine text az chand bakhsh hast
    print('\nEtelaat be dorosti vared shodand.')
    break # agar shart dorost bood halghe while ro break mikone.
  else: # agar vurudi text barabar ba do ghesmat nabood text zir ro print mikone
    print('\nEsm va family shoma faghat bayad do ghesmat bashad.\
    \nNahve neveshtane ghalat: Ali Mohamadi Rad\
    \nNahve neveshtane dorost: Ali MohamadiRad\nDobare talash konid...\n')
    # deghat konin ke badaz inke error print shod dobare halghe while az aval tekrar mishe


my_text_after = my_text. # ? az yek method inja estefade konid ke hameye character haro koochik kone.

print(f'\ninfo ghable function: {my_text}\ninfo bade function: {my_text_after}')

# %% [markdown]
# > benazaretoon `\` haye akhare yek line tooye function e `print` baraye chi estefade shode?
# agar oon ro remove konim chi mishe?
#
# * pas yeki dge az Escape Character hayi ke yad gereftim `\` khali hast va be komake oon mitoonim akhare yek line oon ro bezarim va baghie code emoon ro tooye line e badi benvisim.

# %% [markdown]
# ## 2.
#
# Mitoonin cell haye zir ro khodetoon taghir bedin ta mesle cell e bala va be komake function e print khana tar beshan.
#
# dakhele site e [w3schools](https://www.w3schools.com/python/python_ref_string.asp) berin va yek method baraye string ha peyda konid ke agar kolle string e shoma lower case bood (ex: 'salam khoobi') be shoma True bargardoone va agar hata yeki az character haye string e shoma upper case bood (ex: 'Salam Khoobi') be shoma False ro bargardoone.
#
# * rahe dgei ke mitoonin in method ro peyda konin ine ke chizi ke mikhain ro tooye google search konin.
#
# masalan agar text zir ro search konin in method ro be shoma mige: `string method python to check all characters to be lowercase`
#
# agar search konin mibinin ke...
#
# ![1233.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# > yadetoon bemoone ke `**search kardan**` yeki az mohem tarin kar hayi hast ke shoma bayad be onvane yek barname nevis yad begirin va azash estefade konin. be komake search kardan rahat mitoonin moshkelatetoon ro hal konin va az ghodrate google estefade konin.
#
# Hala ke method ro baladin be komake input o print o method i ke taze yad gereftin yek barname benvisin ke vurudi ro begire va check kone ke hame character esh koochik hast ya na. va khurji ro be komake print va f-string be soorate khanai namayesh bedin.

# %%
# code e tamrin dovom inja
